# %%
#call it with this
#load deps
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from scipy import stats
import re
import time
from GenerateControlFuncs import *
import os


#write versions
import sys
import pkg_resources

# Get the Python version
python_version = sys.version

# Get the list of installed packages with versions
installed_packages = sorted(["{}=={}".format(d.project_name, d.version) for d in pkg_resources.working_set])

# Define output file
output_file = "../Paper_Figures/Package_Info/pythonStep2_environment.txt"

# Write to file
with open(output_file, "w") as f:
    f.write(f"Python Version:\n{python_version}\n\n")
    f.write("Installed Packages:\n")
    f.write("\n".join(installed_packages))

print(f"Python environment details saved to {output_file}")
# Out:
# Python environment details saved to ../Paper_Figures/Package_Info/pythonStep2_environment.txt

# %% [markdown]
# ###Readme
#
# This code will take multithreading, so the more cores you give it the faster it will train.
# The outputs can be used in R Step 5 and 6

# %%
import os
import pandas as pd
from GenerateControlFuncs import *

# ========================
# 1) Load Data
# ========================
AM = pd.read_csv('../Step1_LoadingAndCleaningData/AM.csv')
FM = pd.read_csv('../Step1_LoadingAndCleaningData/FM.csv')
AP = pd.read_csv('../Step1_LoadingAndCleaningData/AP.csv')
FP = pd.read_csv('../Step1_LoadingAndCleaningData/FP.csv')
AMP = pd.read_csv('../Step1_LoadingAndCleaningData/AMP.csv')
FMP = pd.read_csv('../Step1_LoadingAndCleaningData/FMP.csv')

datasets = {
    'FM': FM,
    'AM': AM,
    'AP': AP,
    'FP': FP,
    'FMP': FMP,
    'AMP': AMP
}

# ========================
# 2) Define Best Params
# ========================
best_params = {
    'FM':  {'subsample': 0.8, 'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.6},
    'AM':  {'subsample': 0.8, 'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.6},
    'AP':  {'subsample': 1.0, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 1.0},
    'FP':  {'subsample': 1.0, 'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 1.0},
    'FMP': {'subsample': 0.6, 'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.6},
    'AMP': {'subsample': 0.8, 'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.05, 'colsample_bytree': 0.8}
}

# ========================
# 3) Other Settings
# ========================
selected_groups = ["M_Rapa", "M_Aca", "M_Cana", "M_CR", "M_17aE2", "M_Cont_12"]
k_folds = 10
iters = 1   # for example, if you want 20 repeated CV iterations
output_prefix = "XGBoost_Analysis_10k_20i_details_fig1"
cols_to_ignore = [
    'median_lifespan_increase', 'Grp_Sex', 'Lifespan_Increased2', 'Grp', 
    'Mouse', 'ID', 'group', 'Treatment', 'X18198', 'Condition', 'Sex', 
    'Mouse_ID', 'Unnamed: 0'
]

# ========================
# 4) Run the Analysis
# ========================

results = perform_xgboost_analysis_kfold(
    datasets=datasets,
    selected_groups=selected_groups,
    k=10,
    output_prefix="results",
    cols_to_ignore=cols_to_ignore,
    hyperparam_dict=best_params,
    iters=20,
    save_intermediate=True,           # <--- 
    intermediate_dir="Intermediate"   # <--- optional custom folder
)

# ========================
# 5) Access the Results
# ========================
all_results = results['all_results']
control_results = results['control_results']
group_labels = results['group_labels']

print("\nSummary of results:")
print(f"All results shape: {all_results.shape}")
print(f"Control results shape: {control_results.shape}")

print("\nGroup labels:")
for dataset_name, labels in group_labels.items():
    print(f"{dataset_name}: {labels}")

# Optional: Additional post-analysis
for dataset_name in all_results['Dataset'].unique():
    print(f"\nDataset: {dataset_name}")
    dataset_res = all_results[all_results['Dataset'] == dataset_name]
    for group in dataset_res['Grp_Sex'].unique():
        grp_preds = dataset_res[dataset_res['Grp_Sex'] == group]['Median_Prediction']
        print(f"  {group}: Mean = {grp_preds.mean():.2f}, Std = {grp_preds.std():.2f}")
# Out:
# Starting XGBoost analysis with k-fold cross-validation (XGBoost's own parallelism)
#
# Processing dataset: FM
#
# Starting analysis for dataset: FM
# After adding median_lifespan_increase. Shape: (278, 1058)
# After adding Mouse_ID. Shape: (278, 1059)
# After filtering for selected groups. Shape: (94, 1059)
# After selecting numeric predictors. Shape: (94, 1051)
# Column names cleaned
# After removing columns with NaN or Inf. Shape: (94, 1051)
# Processing fold 1 of 10 (Iteration 0)
#   Training XGBoost model for fold 1, iteration 0
#   Making predictions for fold 1, iteration 0
# Processing fold 2 of 10 (Iteration 0)
#   Training XGBoost model for fold 2, iteration 0
#   Making predictions for fold 2, iteration 0
# Processing fold 3 of 10 (Iteration 0)
#   Training XGBoost model for fold 3, iteration 0
#   Making predictions for fold 3, iteration 0
# Processing fold 4 of 10 (Iteration 0)
#   Training XGBoost model for fold 4, iteration 0
#   Making predictions for fold 4, iteration 0
# Processing fold 5 of 10 (Iteration 0)
#   Training XGBoost model for fold 5, iteration 0
#   Making predictions for fold 5, iteration 0
# Processing fold 6 of 10 (Iteration 0)
#   Training XGBoost model for fold 6, iteration 0
#   Making predictions for fold 6, iteration 0
# Processing fold 7 of 10 (Iteration 0)
#   Training XGBoost model for fold 7, iteration 0
#   Making predictions for fold 7, iteration 0
# Processing fold 8 of 10 (Iteration 0)
#   Training XGBoost model for fold 8, iteration 0
#   Making predictions for fold 8, iteration 0
# Processing fold 9 of 10 (Iteration 0)
#   Training XGBoost model for fold 9, iteration 0
#   Making predictions for fold 9, iteration 0
# Processing fold 10 of 10 (Iteration 0)
#   Training XGBoost model for fold 10, iteration 0
#   Making predictions for fold 10, iteration 0
# Saved intermediate predictions to Intermediate/FM_iter_0.csv
# Processing fold 1 of 10 (Iteration 1)
#   Training XGBoost model for fold 1, iteration 1
#   Making predictions for fold 1, iteration 1
# Processing fold 2 of 10 (Iteration 1)
#   Training XGBoost model for fold 2, iteration 1
#   Making predictions for fold 2, iteration 1
# Processing fold 3 of 10 (Iteration 1)
#   Training XGBoost model for fold 3, iteration 1
#   Making predictions for fold 3, iteration 1
# Processing fold 4 of 10 (Iteration 1)
#   Training XGBoost model for fold 4, iteration 1
#   Making predictions for fold 4, iteration 1
# Processing fold 5 of 10 (Iteration 1)
#   Training XGBoost model for fold 5, iteration 1
#   Making predictions for fold 5, iteration 1
# Processing fold 6 of 10 (Iteration 1)
#   Training XGBoost model for fold 6, iteration 1
#   Making predictions for fold 6, iteration 1
# Processing fold 7 of 10 (Iteration 1)
#   Training XGBoost model for fold 7, iteration 1
#   Making predictions for fold 7, iteration 1
# Processing fold 8 of 10 (Iteration 1)
#   Training XGBoost model for fold 8, iteration 1
#   Making predictions for fold 8, iteration 1
# Processing fold 9 of 10 (Iteration 1)
#   Training XGBoost model for fold 9, iteration 1
#   Making predictions for fold 9, iteration 1
# Processing fold 10 of 10 (Iteration 1)
#   Training XGBoost model for fold 10, iteration 1
#   Making predictions for fold 10, iteration 1
# Saved intermediate predictions to Intermediate/FM_iter_1.csv
# Processing fold 1 of 10 (Iteration 2)
#   Training XGBoost model for fold 1, iteration 2
#   Making predictions for fold 1, iteration 2
# Processing fold 2 of 10 (Iteration 2)
#   Training XGBoost model for fold 2, iteration 2
#   Making predictions for fold 2, iteration 2
# Processing fold 3 of 10 (Iteration 2)
#   Training XGBoost model for fold 3, iteration 2
#   Making predictions for fold 3, iteration 2
# Processing fold 4 of 10 (Iteration 2)
#   Training XGBoost model for fold 4, iteration 2
#   Making predictions for fold 4, iteration 2
# Processing fold 5 of 10 (Iteration 2)
#   Training XGBoost model for fold 5, iteration 2
#   Making predictions for fold 5, iteration 2
# Processing fold 6 of 10 (Iteration 2)
#   Training XGBoost model for fold 6, iteration 2
#   Making predictions for fold 6, iteration 2
# Processing fold 7 of 10 (Iteration 2)
#   Training XGBoost model for fold 7, iteration 2
#   Making predictions for fold 7, iteration 2
# Processing fold 8 of 10 (Iteration 2)
#   Training XGBoost model for fold 8, iteration 2
#   Making predictions for fold 8, iteration 2
# Processing fold 9 of 10 (Iteration 2)
#   Training XGBoost model for fold 9, iteration 2
#   Making predictions for fold 9, iteration 2
# Processing fold 10 of 10 (Iteration 2)
#   Training XGBoost model for fold 10, iteration 2
#   Making predictions for fold 10, iteration 2
# Saved intermediate predictions to Intermediate/FM_iter_2.csv
# Processing fold 1 of 10 (Iteration 3)
#   Training XGBoost model for fold 1, iteration 3
#   Making predictions for fold 1, iteration 3
# Processing fold 2 of 10 (Iteration 3)
#   Training XGBoost model for fold 2, iteration 3
#   Making predictions for fold 2, iteration 3
# Processing fold 3 of 10 (Iteration 3)
#   Training XGBoost model for fold 3, iteration 3
#   Making predictions for fold 3, iteration 3
# Processing fold 4 of 10 (Iteration 3)
#   Training XGBoost model for fold 4, iteration 3
#   Making predictions for fold 4, iteration 3
# Processing fold 5 of 10 (Iteration 3)
#   Training XGBoost model for fold 5, iteration 3
#   Making predictions for fold 5, iteration 3
# Processing fold 6 of 10 (Iteration 3)
#   Training XGBoost model for fold 6, iteration 3
#   Making predictions for fold 6, iteration 3
# Processing fold 7 of 10 (Iteration 3)
#   Training XGBoost model for fold 7, iteration 3
#   Making predictions for fold 7, iteration 3
# Processing fold 8 of 10 (Iteration 3)
#   Training XGBoost model for fold 8, iteration 3
#   Making predictions for fold 8, iteration 3
# Processing fold 9 of 10 (Iteration 3)
#   Training XGBoost model for fold 9, iteration 3
#   Making predictions for fold 9, iteration 3
# Processing fold 10 of 10 (Iteration 3)
#   Training XGBoost model for fold 10, iteration 3
#   Making predictions for fold 10, iteration 3
# Saved intermediate predictions to Intermediate/FM_iter_3.csv
# Processing fold 1 of 10 (Iteration 4)
#   Training XGBoost model for fold 1, iteration 4
#   Making predictions for fold 1, iteration 4
# Processing fold 2 of 10 (Iteration 4)
#   Training XGBoost model for fold 2, iteration 4
#   Making predictions for fold 2, iteration 4
# Processing fold 3 of 10 (Iteration 4)
#   Training XGBoost model for fold 3, iteration 4
#   Making predictions for fold 3, iteration 4
# Processing fold 4 of 10 (Iteration 4)
#   Training XGBoost model for fold 4, iteration 4
#   Making predictions for fold 4, iteration 4
# Processing fold 5 of 10 (Iteration 4)
#   Training XGBoost model for fold 5, iteration 4
#   Making predictions for fold 5, iteration 4
# Processing fold 6 of 10 (Iteration 4)
#   Training XGBoost model for fold 6, iteration 4
#   Making predictions for fold 6, iteration 4
# Processing fold 7 of 10 (Iteration 4)
#   Training XGBoost model for fold 7, iteration 4
#   Making predictions for fold 7, iteration 4
# Processing fold 8 of 10 (Iteration 4)
#   Training XGBoost model for fold 8, iteration 4
#   Making predictions for fold 8, iteration 4
# Processing fold 9 of 10 (Iteration 4)
#   Training XGBoost model for fold 9, iteration 4
#   Making predictions for fold 9, iteration 4
# Processing fold 10 of 10 (Iteration 4)
#   Training XGBoost model for fold 10, iteration 4
#   Making predictions for fold 10, iteration 4
# Saved intermediate predictions to Intermediate/FM_iter_4.csv
# Processing fold 1 of 10 (Iteration 5)
#   Training XGBoost model for fold 1, iteration 5
#   Making predictions for fold 1, iteration 5
# Processing fold 2 of 10 (Iteration 5)
#   Training XGBoost model for fold 2, iteration 5
#   Making predictions for fold 2, iteration 5
# Processing fold 3 of 10 (Iteration 5)
#   Training XGBoost model for fold 3, iteration 5
#   Making predictions for fold 3, iteration 5
# Processing fold 4 of 10 (Iteration 5)
#   Training XGBoost model for fold 4, iteration 5
#   Making predictions for fold 4, iteration 5
# Processing fold 5 of 10 (Iteration 5)
#   Training XGBoost model for fold 5, iteration 5
#   Making predictions for fold 5, iteration 5
# Processing fold 6 of 10 (Iteration 5)
#   Training XGBoost model for fold 6, iteration 5
#   Making predictions for fold 6, iteration 5
# Processing fold 7 of 10 (Iteration 5)
#   Training XGBoost model for fold 7, iteration 5
#   Making predictions for fold 7, iteration 5
# Processing fold 8 of 10 (Iteration 5)
#   Training XGBoost model for fold 8, iteration 5
#   Making predictions for fold 8, iteration 5
# Processing fold 9 of 10 (Iteration 5)
#   Training XGBoost model for fold 9, iteration 5
#   Making predictions for fold 9, iteration 5
# Processing fold 10 of 10 (Iteration 5)
#   Training XGBoost model for fold 10, iteration 5
#   Making predictions for fold 10, iteration 5
# Saved intermediate predictions to Intermediate/FM_iter_5.csv
# Processing fold 1 of 10 (Iteration 6)
#   Training XGBoost model for fold 1, iteration 6
#   Making predictions for fold 1, iteration 6
# Processing fold 2 of 10 (Iteration 6)
#   Training XGBoost model for fold 2, iteration 6
#   Making predictions for fold 2, iteration 6
# Processing fold 3 of 10 (Iteration 6)
#   Training XGBoost model for fold 3, iteration 6
#   Making predictions for fold 3, iteration 6
# Processing fold 4 of 10 (Iteration 6)
#   Training XGBoost model for fold 4, iteration 6
#   Making predictions for fold 4, iteration 6
# Processing fold 5 of 10 (Iteration 6)
#   Training XGBoost model for fold 5, iteration 6
#   Making predictions for fold 5, iteration 6
# Processing fold 6 of 10 (Iteration 6)
#   Training XGBoost model for fold 6, iteration 6
#   Making predictions for fold 6, iteration 6
# Processing fold 7 of 10 (Iteration 6)
#   Training XGBoost model for fold 7, iteration 6
#   Making predictions for fold 7, iteration 6
# Processing fold 8 of 10 (Iteration 6)
#   Training XGBoost model for fold 8, iteration 6
#   Making predictions for fold 8, iteration 6
# Processing fold 9 of 10 (Iteration 6)
#   Training XGBoost model for fold 9, iteration 6
#   Making predictions for fold 9, iteration 6
# Processing fold 10 of 10 (Iteration 6)
#   Training XGBoost model for fold 10, iteration 6
#   Making predictions for fold 10, iteration 6
# Saved intermediate predictions to Intermediate/FM_iter_6.csv
# Processing fold 1 of 10 (Iteration 7)
#   Training XGBoost model for fold 1, iteration 7
#   Making predictions for fold 1, iteration 7
# Processing fold 2 of 10 (Iteration 7)
#   Training XGBoost model for fold 2, iteration 7
#   Making predictions for fold 2, iteration 7
# Processing fold 3 of 10 (Iteration 7)
#   Training XGBoost model for fold 3, iteration 7
#   Making predictions for fold 3, iteration 7
# Processing fold 4 of 10 (Iteration 7)
#   Training XGBoost model for fold 4, iteration 7
#   Making predictions for fold 4, iteration 7
# Processing fold 5 of 10 (Iteration 7)
#   Training XGBoost model for fold 5, iteration 7
#   Making predictions for fold 5, iteration 7
# Processing fold 6 of 10 (Iteration 7)
#   Training XGBoost model for fold 6, iteration 7
#   Making predictions for fold 6, iteration 7
# Processing fold 7 of 10 (Iteration 7)
#   Training XGBoost model for fold 7, iteration 7
#   Making predictions for fold 7, iteration 7
# Processing fold 8 of 10 (Iteration 7)
#   Training XGBoost model for fold 8, iteration 7
#   Making predictions for fold 8, iteration 7
# Processing fold 9 of 10 (Iteration 7)
#   Training XGBoost model for fold 9, iteration 7
#   Making predictions for fold 9, iteration 7
# Processing fold 10 of 10 (Iteration 7)
#   Training XGBoost model for fold 10, iteration 7
#   Making predictions for fold 10, iteration 7
# Saved intermediate predictions to Intermediate/FM_iter_7.csv
# Processing fold 1 of 10 (Iteration 8)
#   Training XGBoost model for fold 1, iteration 8
#   Making predictions for fold 1, iteration 8
# Processing fold 2 of 10 (Iteration 8)
#   Training XGBoost model for fold 2, iteration 8
#   Making predictions for fold 2, iteration 8
# Processing fold 3 of 10 (Iteration 8)
#   Training XGBoost model for fold 3, iteration 8
#   Making predictions for fold 3, iteration 8
# Processing fold 4 of 10 (Iteration 8)
#   Training XGBoost model for fold 4, iteration 8
#   Making predictions for fold 4, iteration 8
# Processing fold 5 of 10 (Iteration 8)
#   Training XGBoost model for fold 5, iteration 8
#   Making predictions for fold 5, iteration 8
# Processing fold 6 of 10 (Iteration 8)
#   Training XGBoost model for fold 6, iteration 8
#   Making predictions for fold 6, iteration 8
# Processing fold 7 of 10 (Iteration 8)
#   Training XGBoost model for fold 7, iteration 8
#   Making predictions for fold 7, iteration 8
# Processing fold 8 of 10 (Iteration 8)
#   Training XGBoost model for fold 8, iteration 8
#   Making predictions for fold 8, iteration 8
# Processing fold 9 of 10 (Iteration 8)
#   Training XGBoost model for fold 9, iteration 8
#   Making predictions for fold 9, iteration 8
# Processing fold 10 of 10 (Iteration 8)
#   Training XGBoost model for fold 10, iteration 8
#   Making predictions for fold 10, iteration 8
# Saved intermediate predictions to Intermediate/FM_iter_8.csv
# Processing fold 1 of 10 (Iteration 9)
#   Training XGBoost model for fold 1, iteration 9
#   Making predictions for fold 1, iteration 9
# Processing fold 2 of 10 (Iteration 9)
#   Training XGBoost model for fold 2, iteration 9
#   Making predictions for fold 2, iteration 9
# Processing fold 3 of 10 (Iteration 9)
#   Training XGBoost model for fold 3, iteration 9
#   Making predictions for fold 3, iteration 9
# Processing fold 4 of 10 (Iteration 9)
#   Training XGBoost model for fold 4, iteration 9
#   Making predictions for fold 4, iteration 9
# Processing fold 5 of 10 (Iteration 9)
#   Training XGBoost model for fold 5, iteration 9
#   Making predictions for fold 5, iteration 9
# Processing fold 6 of 10 (Iteration 9)
#   Training XGBoost model for fold 6, iteration 9
#   Making predictions for fold 6, iteration 9
# Processing fold 7 of 10 (Iteration 9)
#   Training XGBoost model for fold 7, iteration 9
#   Making predictions for fold 7, iteration 9
# Processing fold 8 of 10 (Iteration 9)
#   Training XGBoost model for fold 8, iteration 9
#   Making predictions for fold 8, iteration 9
# Processing fold 9 of 10 (Iteration 9)
#   Training XGBoost model for fold 9, iteration 9
#   Making predictions for fold 9, iteration 9
# Processing fold 10 of 10 (Iteration 9)
#   Training XGBoost model for fold 10, iteration 9
#   Making predictions for fold 10, iteration 9
# Saved intermediate predictions to Intermediate/FM_iter_9.csv
# Processing fold 1 of 10 (Iteration 10)
#   Training XGBoost model for fold 1, iteration 10
#   Making predictions for fold 1, iteration 10
# Processing fold 2 of 10 (Iteration 10)
#   Training XGBoost model for fold 2, iteration 10
#   Making predictions for fold 2, iteration 10
# Processing fold 3 of 10 (Iteration 10)
#   Training XGBoost model for fold 3, iteration 10
#   Making predictions for fold 3, iteration 10
# Processing fold 4 of 10 (Iteration 10)
#   Training XGBoost model for fold 4, iteration 10
#   Making predictions for fold 4, iteration 10
# Processing fold 5 of 10 (Iteration 10)
#   Training XGBoost model for fold 5, iteration 10
#   Making predictions for fold 5, iteration 10
# Processing fold 6 of 10 (Iteration 10)
#   Training XGBoost model for fold 6, iteration 10
#   Making predictions for fold 6, iteration 10
# Processing fold 7 of 10 (Iteration 10)
#   Training XGBoost model for fold 7, iteration 10
#   Making predictions for fold 7, iteration 10
# Processing fold 8 of 10 (Iteration 10)
#   Training XGBoost model for fold 8, iteration 10
#   Making predictions for fold 8, iteration 10
# Processing fold 9 of 10 (Iteration 10)
#   Training XGBoost model for fold 9, iteration 10
#   Making predictions for fold 9, iteration 10
# Processing fold 10 of 10 (Iteration 10)
#   Training XGBoost model for fold 10, iteration 10
#   Making predictions for fold 10, iteration 10
# Saved intermediate predictions to Intermediate/FM_iter_10.csv
# Processing fold 1 of 10 (Iteration 11)
#   Training XGBoost model for fold 1, iteration 11
#   Making predictions for fold 1, iteration 11
# Processing fold 2 of 10 (Iteration 11)
#   Training XGBoost model for fold 2, iteration 11
#   Making predictions for fold 2, iteration 11
# Processing fold 3 of 10 (Iteration 11)
#   Training XGBoost model for fold 3, iteration 11
#   Making predictions for fold 3, iteration 11
# Processing fold 4 of 10 (Iteration 11)
#   Training XGBoost model for fold 4, iteration 11
#   Making predictions for fold 4, iteration 11
# Processing fold 5 of 10 (Iteration 11)
#   Training XGBoost model for fold 5, iteration 11
#   Making predictions for fold 5, iteration 11
# Processing fold 6 of 10 (Iteration 11)
#   Training XGBoost model for fold 6, iteration 11
#   Making predictions for fold 6, iteration 11
# Processing fold 7 of 10 (Iteration 11)
#   Training XGBoost model for fold 7, iteration 11
#   Making predictions for fold 7, iteration 11
# Processing fold 8 of 10 (Iteration 11)
#   Training XGBoost model for fold 8, iteration 11
#   Making predictions for fold 8, iteration 11
# Processing fold 9 of 10 (Iteration 11)
#   Training XGBoost model for fold 9, iteration 11
#   Making predictions for fold 9, iteration 11
# Processing fold 10 of 10 (Iteration 11)
#   Training XGBoost model for fold 10, iteration 11
#   Making predictions for fold 10, iteration 11
# Saved intermediate predictions to Intermediate/FM_iter_11.csv
# Processing fold 1 of 10 (Iteration 12)
#   Training XGBoost model for fold 1, iteration 12
#   Making predictions for fold 1, iteration 12
# Processing fold 2 of 10 (Iteration 12)
#   Training XGBoost model for fold 2, iteration 12
#   Making predictions for fold 2, iteration 12
# Processing fold 3 of 10 (Iteration 12)
#   Training XGBoost model for fold 3, iteration 12
#   Making predictions for fold 3, iteration 12
# Processing fold 4 of 10 (Iteration 12)
#   Training XGBoost model for fold 4, iteration 12
#   Making predictions for fold 4, iteration 12
# Processing fold 5 of 10 (Iteration 12)
#   Training XGBoost model for fold 5, iteration 12
#   Making predictions for fold 5, iteration 12
# Processing fold 6 of 10 (Iteration 12)
#   Training XGBoost model for fold 6, iteration 12
#   Making predictions for fold 6, iteration 12
# Processing fold 7 of 10 (Iteration 12)
#   Training XGBoost model for fold 7, iteration 12
#   Making predictions for fold 7, iteration 12
# Processing fold 8 of 10 (Iteration 12)
#   Training XGBoost model for fold 8, iteration 12
#   Making predictions for fold 8, iteration 12
# Processing fold 9 of 10 (Iteration 12)
#   Training XGBoost model for fold 9, iteration 12
#   Making predictions for fold 9, iteration 12
# Processing fold 10 of 10 (Iteration 12)
#   Training XGBoost model for fold 10, iteration 12
#   Making predictions for fold 10, iteration 12
# Saved intermediate predictions to Intermediate/FM_iter_12.csv
# Processing fold 1 of 10 (Iteration 13)
#   Training XGBoost model for fold 1, iteration 13
#   Making predictions for fold 1, iteration 13
# Processing fold 2 of 10 (Iteration 13)
#   Training XGBoost model for fold 2, iteration 13
#   Making predictions for fold 2, iteration 13
# Processing fold 3 of 10 (Iteration 13)
#   Training XGBoost model for fold 3, iteration 13
#   Making predictions for fold 3, iteration 13
# Processing fold 4 of 10 (Iteration 13)
#   Training XGBoost model for fold 4, iteration 13
#   Making predictions for fold 4, iteration 13
# Processing fold 5 of 10 (Iteration 13)
#   Training XGBoost model for fold 5, iteration 13
#   Making predictions for fold 5, iteration 13
# Processing fold 6 of 10 (Iteration 13)
#   Training XGBoost model for fold 6, iteration 13
#   Making predictions for fold 6, iteration 13
# Processing fold 7 of 10 (Iteration 13)
#   Training XGBoost model for fold 7, iteration 13
#   Making predictions for fold 7, iteration 13
# Processing fold 8 of 10 (Iteration 13)
#   Training XGBoost model for fold 8, iteration 13
#   Making predictions for fold 8, iteration 13
# Processing fold 9 of 10 (Iteration 13)
#   Training XGBoost model for fold 9, iteration 13
#   Making predictions for fold 9, iteration 13
# Processing fold 10 of 10 (Iteration 13)
#   Training XGBoost model for fold 10, iteration 13
#   Making predictions for fold 10, iteration 13
# Saved intermediate predictions to Intermediate/FM_iter_13.csv
# Processing fold 1 of 10 (Iteration 14)
#   Training XGBoost model for fold 1, iteration 14
#   Making predictions for fold 1, iteration 14
# Processing fold 2 of 10 (Iteration 14)
#   Training XGBoost model for fold 2, iteration 14
#   Making predictions for fold 2, iteration 14
# Processing fold 3 of 10 (Iteration 14)
#   Training XGBoost model for fold 3, iteration 14
#   Making predictions for fold 3, iteration 14
# Processing fold 4 of 10 (Iteration 14)
#   Training XGBoost model for fold 4, iteration 14
#   Making predictions for fold 4, iteration 14
# Processing fold 5 of 10 (Iteration 14)
#   Training XGBoost model for fold 5, iteration 14
#   Making predictions for fold 5, iteration 14
# Processing fold 6 of 10 (Iteration 14)
#   Training XGBoost model for fold 6, iteration 14
#   Making predictions for fold 6, iteration 14
# Processing fold 7 of 10 (Iteration 14)
#   Training XGBoost model for fold 7, iteration 14
#   Making predictions for fold 7, iteration 14
# Processing fold 8 of 10 (Iteration 14)
#   Training XGBoost model for fold 8, iteration 14
#   Making predictions for fold 8, iteration 14
# Processing fold 9 of 10 (Iteration 14)
#   Training XGBoost model for fold 9, iteration 14
#   Making predictions for fold 9, iteration 14
# Processing fold 10 of 10 (Iteration 14)
#   Training XGBoost model for fold 10, iteration 14
#   Making predictions for fold 10, iteration 14
# Saved intermediate predictions to Intermediate/FM_iter_14.csv
# Processing fold 1 of 10 (Iteration 15)
#   Training XGBoost model for fold 1, iteration 15
#   Making predictions for fold 1, iteration 15
# Processing fold 2 of 10 (Iteration 15)
#   Training XGBoost model for fold 2, iteration 15
#   Making predictions for fold 2, iteration 15
# Processing fold 3 of 10 (Iteration 15)
#   Training XGBoost model for fold 3, iteration 15
#   Making predictions for fold 3, iteration 15
# Processing fold 4 of 10 (Iteration 15)
#   Training XGBoost model for fold 4, iteration 15
#   Making predictions for fold 4, iteration 15
# Processing fold 5 of 10 (Iteration 15)
#   Training XGBoost model for fold 5, iteration 15
#   Making predictions for fold 5, iteration 15
# Processing fold 6 of 10 (Iteration 15)
#   Training XGBoost model for fold 6, iteration 15
#   Making predictions for fold 6, iteration 15
# Processing fold 7 of 10 (Iteration 15)
#   Training XGBoost model for fold 7, iteration 15
#   Making predictions for fold 7, iteration 15
# Processing fold 8 of 10 (Iteration 15)
#   Training XGBoost model for fold 8, iteration 15
#   Making predictions for fold 8, iteration 15
# Processing fold 9 of 10 (Iteration 15)
#   Training XGBoost model for fold 9, iteration 15
#   Making predictions for fold 9, iteration 15
# Processing fold 10 of 10 (Iteration 15)
#   Training XGBoost model for fold 10, iteration 15
#   Making predictions for fold 10, iteration 15
# Saved intermediate predictions to Intermediate/FM_iter_15.csv
# Processing fold 1 of 10 (Iteration 16)
#   Training XGBoost model for fold 1, iteration 16
#   Making predictions for fold 1, iteration 16
# Processing fold 2 of 10 (Iteration 16)
#   Training XGBoost model for fold 2, iteration 16
#   Making predictions for fold 2, iteration 16
# Processing fold 3 of 10 (Iteration 16)
#   Training XGBoost model for fold 3, iteration 16
#   Making predictions for fold 3, iteration 16
# Processing fold 4 of 10 (Iteration 16)
#   Training XGBoost model for fold 4, iteration 16
#   Making predictions for fold 4, iteration 16
# Processing fold 5 of 10 (Iteration 16)
#   Training XGBoost model for fold 5, iteration 16
#   Making predictions for fold 5, iteration 16
# Processing fold 6 of 10 (Iteration 16)
#   Training XGBoost model for fold 6, iteration 16
#   Making predictions for fold 6, iteration 16
# Processing fold 7 of 10 (Iteration 16)
#   Training XGBoost model for fold 7, iteration 16
#   Making predictions for fold 7, iteration 16
# Processing fold 8 of 10 (Iteration 16)
#   Training XGBoost model for fold 8, iteration 16
#   Making predictions for fold 8, iteration 16
# Processing fold 9 of 10 (Iteration 16)
#   Training XGBoost model for fold 9, iteration 16
#   Making predictions for fold 9, iteration 16
# Processing fold 10 of 10 (Iteration 16)
#   Training XGBoost model for fold 10, iteration 16
#   Making predictions for fold 10, iteration 16
# Saved intermediate predictions to Intermediate/FM_iter_16.csv
# Processing fold 1 of 10 (Iteration 17)
#   Training XGBoost model for fold 1, iteration 17
#   Making predictions for fold 1, iteration 17
# Processing fold 2 of 10 (Iteration 17)
#   Training XGBoost model for fold 2, iteration 17
#   Making predictions for fold 2, iteration 17
# Processing fold 3 of 10 (Iteration 17)
#   Training XGBoost model for fold 3, iteration 17
#   Making predictions for fold 3, iteration 17
# Processing fold 4 of 10 (Iteration 17)
#   Training XGBoost model for fold 4, iteration 17
#   Making predictions for fold 4, iteration 17
# Processing fold 5 of 10 (Iteration 17)
#   Training XGBoost model for fold 5, iteration 17
#   Making predictions for fold 5, iteration 17
# Processing fold 6 of 10 (Iteration 17)
#   Training XGBoost model for fold 6, iteration 17
#   Making predictions for fold 6, iteration 17
# Processing fold 7 of 10 (Iteration 17)
#   Training XGBoost model for fold 7, iteration 17
#   Making predictions for fold 7, iteration 17
# Processing fold 8 of 10 (Iteration 17)
#   Training XGBoost model for fold 8, iteration 17
#   Making predictions for fold 8, iteration 17
# Processing fold 9 of 10 (Iteration 17)
#   Training XGBoost model for fold 9, iteration 17
#   Making predictions for fold 9, iteration 17
# Processing fold 10 of 10 (Iteration 17)
#   Training XGBoost model for fold 10, iteration 17
#   Making predictions for fold 10, iteration 17
# Saved intermediate predictions to Intermediate/FM_iter_17.csv
# Processing fold 1 of 10 (Iteration 18)
#   Training XGBoost model for fold 1, iteration 18
#   Making predictions for fold 1, iteration 18
# Processing fold 2 of 10 (Iteration 18)
#   Training XGBoost model for fold 2, iteration 18
#   Making predictions for fold 2, iteration 18
# Processing fold 3 of 10 (Iteration 18)
#   Training XGBoost model for fold 3, iteration 18
#   Making predictions for fold 3, iteration 18
# Processing fold 4 of 10 (Iteration 18)
#   Training XGBoost model for fold 4, iteration 18
#   Making predictions for fold 4, iteration 18
# Processing fold 5 of 10 (Iteration 18)
#   Training XGBoost model for fold 5, iteration 18
#   Making predictions for fold 5, iteration 18
# Processing fold 6 of 10 (Iteration 18)
#   Training XGBoost model for fold 6, iteration 18
#   Making predictions for fold 6, iteration 18
# Processing fold 7 of 10 (Iteration 18)
#   Training XGBoost model for fold 7, iteration 18
#   Making predictions for fold 7, iteration 18
# Processing fold 8 of 10 (Iteration 18)
#   Training XGBoost model for fold 8, iteration 18
#   Making predictions for fold 8, iteration 18
# Processing fold 9 of 10 (Iteration 18)
#   Training XGBoost model for fold 9, iteration 18
#   Making predictions for fold 9, iteration 18
# Processing fold 10 of 10 (Iteration 18)
#   Training XGBoost model for fold 10, iteration 18
#   Making predictions for fold 10, iteration 18
# Saved intermediate predictions to Intermediate/FM_iter_18.csv
# Processing fold 1 of 10 (Iteration 19)
#   Training XGBoost model for fold 1, iteration 19
#   Making predictions for fold 1, iteration 19
# Processing fold 2 of 10 (Iteration 19)
#   Training XGBoost model for fold 2, iteration 19
#   Making predictions for fold 2, iteration 19
# Processing fold 3 of 10 (Iteration 19)
#   Training XGBoost model for fold 3, iteration 19
#   Making predictions for fold 3, iteration 19
# Processing fold 4 of 10 (Iteration 19)
#   Training XGBoost model for fold 4, iteration 19
#   Making predictions for fold 4, iteration 19
# Processing fold 5 of 10 (Iteration 19)
#   Training XGBoost model for fold 5, iteration 19
#   Making predictions for fold 5, iteration 19
# Processing fold 6 of 10 (Iteration 19)
#   Training XGBoost model for fold 6, iteration 19
#   Making predictions for fold 6, iteration 19
# Processing fold 7 of 10 (Iteration 19)
#   Training XGBoost model for fold 7, iteration 19
#   Making predictions for fold 7, iteration 19
# Processing fold 8 of 10 (Iteration 19)
#   Training XGBoost model for fold 8, iteration 19
#   Making predictions for fold 8, iteration 19
# Processing fold 9 of 10 (Iteration 19)
#   Training XGBoost model for fold 9, iteration 19
#   Making predictions for fold 9, iteration 19
# Processing fold 10 of 10 (Iteration 19)
#   Training XGBoost model for fold 10, iteration 19
#   Making predictions for fold 10, iteration 19
# Saved intermediate predictions to Intermediate/FM_iter_19.csv
# Re-reading partial predictions from FM to combine everything.
# Concatenating results from all folds/iterations for final stats.
# Analysis completed for dataset: FM
# Results added for FM
# Control results added for FM
# All predictions added for FM
# Group labels recorded for FM
#
# Processing dataset: AM
#
# Starting analysis for dataset: AM
# After adding median_lifespan_increase. Shape: (278, 12327)
# After adding Mouse_ID. Shape: (278, 12328)
# After filtering for selected groups. Shape: (94, 12328)
# After selecting numeric predictors. Shape: (94, 12320)
# Column names cleaned
# After removing columns with NaN or Inf. Shape: (94, 12319)
# Processing fold 1 of 10 (Iteration 0)
#   Training XGBoost model for fold 1, iteration 0
#   Making predictions for fold 1, iteration 0
# Processing fold 2 of 10 (Iteration 0)
#   Training XGBoost model for fold 2, iteration 0
#   Making predictions for fold 2, iteration 0
# Processing fold 3 of 10 (Iteration 0)
#   Training XGBoost model for fold 3, iteration 0
#   Making predictions for fold 3, iteration 0
# Processing fold 4 of 10 (Iteration 0)
#   Training XGBoost model for fold 4, iteration 0
#   Making predictions for fold 4, iteration 0
# Processing fold 5 of 10 (Iteration 0)
#   Training XGBoost model for fold 5, iteration 0
#   Making predictions for fold 5, iteration 0
# Processing fold 6 of 10 (Iteration 0)
#   Training XGBoost model for fold 6, iteration 0
#   Making predictions for fold 6, iteration 0
# Processing fold 7 of 10 (Iteration 0)
#   Training XGBoost model for fold 7, iteration 0
#   Making predictions for fold 7, iteration 0
# Processing fold 8 of 10 (Iteration 0)
#   Training XGBoost model for fold 8, iteration 0
#   Making predictions for fold 8, iteration 0
# Processing fold 9 of 10 (Iteration 0)
#   Training XGBoost model for fold 9, iteration 0
#   Making predictions for fold 9, iteration 0
# Processing fold 10 of 10 (Iteration 0)
#   Training XGBoost model for fold 10, iteration 0
#   Making predictions for fold 10, iteration 0
# Saved intermediate predictions to Intermediate/AM_iter_0.csv
# Processing fold 1 of 10 (Iteration 1)
#   Training XGBoost model for fold 1, iteration 1
#   Making predictions for fold 1, iteration 1
# Processing fold 2 of 10 (Iteration 1)
#   Training XGBoost model for fold 2, iteration 1
#   Making predictions for fold 2, iteration 1
# Processing fold 3 of 10 (Iteration 1)
#   Training XGBoost model for fold 3, iteration 1
#   Making predictions for fold 3, iteration 1
# Processing fold 4 of 10 (Iteration 1)
#   Training XGBoost model for fold 4, iteration 1
#   Making predictions for fold 4, iteration 1
# Processing fold 5 of 10 (Iteration 1)
#   Training XGBoost model for fold 5, iteration 1
#   Making predictions for fold 5, iteration 1
# Processing fold 6 of 10 (Iteration 1)
#   Training XGBoost model for fold 6, iteration 1
#   Making predictions for fold 6, iteration 1
# Processing fold 7 of 10 (Iteration 1)
#   Training XGBoost model for fold 7, iteration 1
#   Making predictions for fold 7, iteration 1
# Processing fold 8 of 10 (Iteration 1)
#   Training XGBoost model for fold 8, iteration 1
#   Making predictions for fold 8, iteration 1
# Processing fold 9 of 10 (Iteration 1)
#   Training XGBoost model for fold 9, iteration 1
#   Making predictions for fold 9, iteration 1
# Processing fold 10 of 10 (Iteration 1)
#   Training XGBoost model for fold 10, iteration 1
#   Making predictions for fold 10, iteration 1
# Saved intermediate predictions to Intermediate/AM_iter_1.csv
# Processing fold 1 of 10 (Iteration 2)
#   Training XGBoost model for fold 1, iteration 2
#   Making predictions for fold 1, iteration 2
# Processing fold 2 of 10 (Iteration 2)
#   Training XGBoost model for fold 2, iteration 2
#   Making predictions for fold 2, iteration 2
# Processing fold 3 of 10 (Iteration 2)
#   Training XGBoost model for fold 3, iteration 2
#   Making predictions for fold 3, iteration 2
# Processing fold 4 of 10 (Iteration 2)
#   Training XGBoost model for fold 4, iteration 2
#   Making predictions for fold 4, iteration 2
# Processing fold 5 of 10 (Iteration 2)
#   Training XGBoost model for fold 5, iteration 2
#   Making predictions for fold 5, iteration 2
# Processing fold 6 of 10 (Iteration 2)
#   Training XGBoost model for fold 6, iteration 2
#   Making predictions for fold 6, iteration 2
# Processing fold 7 of 10 (Iteration 2)
#   Training XGBoost model for fold 7, iteration 2
#   Making predictions for fold 7, iteration 2
# Processing fold 8 of 10 (Iteration 2)
#   Training XGBoost model for fold 8, iteration 2
#   Making predictions for fold 8, iteration 2
# Processing fold 9 of 10 (Iteration 2)
#   Training XGBoost model for fold 9, iteration 2
#   Making predictions for fold 9, iteration 2
# Processing fold 10 of 10 (Iteration 2)
#   Training XGBoost model for fold 10, iteration 2
#   Making predictions for fold 10, iteration 2
# Saved intermediate predictions to Intermediate/AM_iter_2.csv
# Processing fold 1 of 10 (Iteration 3)
#   Training XGBoost model for fold 1, iteration 3
#   Making predictions for fold 1, iteration 3
# Processing fold 2 of 10 (Iteration 3)
#   Training XGBoost model for fold 2, iteration 3
#   Making predictions for fold 2, iteration 3
# Processing fold 3 of 10 (Iteration 3)
#   Training XGBoost model for fold 3, iteration 3
#   Making predictions for fold 3, iteration 3
# Processing fold 4 of 10 (Iteration 3)
#   Training XGBoost model for fold 4, iteration 3
#   Making predictions for fold 4, iteration 3
# Processing fold 5 of 10 (Iteration 3)
#   Training XGBoost model for fold 5, iteration 3
#   Making predictions for fold 5, iteration 3
# Processing fold 6 of 10 (Iteration 3)
#   Training XGBoost model for fold 6, iteration 3
#   Making predictions for fold 6, iteration 3
# Processing fold 7 of 10 (Iteration 3)
#   Training XGBoost model for fold 7, iteration 3
#   Making predictions for fold 7, iteration 3
# Processing fold 8 of 10 (Iteration 3)
#   Training XGBoost model for fold 8, iteration 3
#   Making predictions for fold 8, iteration 3
# Processing fold 9 of 10 (Iteration 3)
#   Training XGBoost model for fold 9, iteration 3
#   Making predictions for fold 9, iteration 3
# Processing fold 10 of 10 (Iteration 3)
#   Training XGBoost model for fold 10, iteration 3
#   Making predictions for fold 10, iteration 3
# Saved intermediate predictions to Intermediate/AM_iter_3.csv
# Processing fold 1 of 10 (Iteration 4)
#   Training XGBoost model for fold 1, iteration 4
#   Making predictions for fold 1, iteration 4
# Processing fold 2 of 10 (Iteration 4)
#   Training XGBoost model for fold 2, iteration 4
#   Making predictions for fold 2, iteration 4
# Processing fold 3 of 10 (Iteration 4)
#   Training XGBoost model for fold 3, iteration 4
#   Making predictions for fold 3, iteration 4
# Processing fold 4 of 10 (Iteration 4)
#   Training XGBoost model for fold 4, iteration 4
#   Making predictions for fold 4, iteration 4
# Processing fold 5 of 10 (Iteration 4)
#   Training XGBoost model for fold 5, iteration 4
#   Making predictions for fold 5, iteration 4
# Processing fold 6 of 10 (Iteration 4)
#   Training XGBoost model for fold 6, iteration 4
#   Making predictions for fold 6, iteration 4
# Processing fold 7 of 10 (Iteration 4)
#   Training XGBoost model for fold 7, iteration 4
#   Making predictions for fold 7, iteration 4
# Processing fold 8 of 10 (Iteration 4)
#   Training XGBoost model for fold 8, iteration 4
#   Making predictions for fold 8, iteration 4
# Processing fold 9 of 10 (Iteration 4)
#   Training XGBoost model for fold 9, iteration 4
#   Making predictions for fold 9, iteration 4
# Processing fold 10 of 10 (Iteration 4)
#   Training XGBoost model for fold 10, iteration 4
#   Making predictions for fold 10, iteration 4
# Saved intermediate predictions to Intermediate/AM_iter_4.csv
# Processing fold 1 of 10 (Iteration 5)
#   Training XGBoost model for fold 1, iteration 5
#   Making predictions for fold 1, iteration 5
# Processing fold 2 of 10 (Iteration 5)
#   Training XGBoost model for fold 2, iteration 5
#   Making predictions for fold 2, iteration 5
# Processing fold 3 of 10 (Iteration 5)
#   Training XGBoost model for fold 3, iteration 5
#   Making predictions for fold 3, iteration 5
# Processing fold 4 of 10 (Iteration 5)
#   Training XGBoost model for fold 4, iteration 5
#   Making predictions for fold 4, iteration 5
# Processing fold 5 of 10 (Iteration 5)
#   Training XGBoost model for fold 5, iteration 5
#   Making predictions for fold 5, iteration 5
# Processing fold 6 of 10 (Iteration 5)
#   Training XGBoost model for fold 6, iteration 5
#   Making predictions for fold 6, iteration 5
# Processing fold 7 of 10 (Iteration 5)
#   Training XGBoost model for fold 7, iteration 5
#   Making predictions for fold 7, iteration 5
# Processing fold 8 of 10 (Iteration 5)
#   Training XGBoost model for fold 8, iteration 5
#   Making predictions for fold 8, iteration 5
# Processing fold 9 of 10 (Iteration 5)
#   Training XGBoost model for fold 9, iteration 5
#   Making predictions for fold 9, iteration 5
# Processing fold 10 of 10 (Iteration 5)
#   Training XGBoost model for fold 10, iteration 5
#   Making predictions for fold 10, iteration 5
# Saved intermediate predictions to Intermediate/AM_iter_5.csv
# Processing fold 1 of 10 (Iteration 6)
#   Training XGBoost model for fold 1, iteration 6
#   Making predictions for fold 1, iteration 6
# Processing fold 2 of 10 (Iteration 6)
#   Training XGBoost model for fold 2, iteration 6
#   Making predictions for fold 2, iteration 6
# Processing fold 3 of 10 (Iteration 6)
#   Training XGBoost model for fold 3, iteration 6
#   Making predictions for fold 3, iteration 6
# Processing fold 4 of 10 (Iteration 6)
#   Training XGBoost model for fold 4, iteration 6
#   Making predictions for fold 4, iteration 6
# Processing fold 5 of 10 (Iteration 6)
#   Training XGBoost model for fold 5, iteration 6
#   Making predictions for fold 5, iteration 6
# Processing fold 6 of 10 (Iteration 6)
#   Training XGBoost model for fold 6, iteration 6
#   Making predictions for fold 6, iteration 6
# Processing fold 7 of 10 (Iteration 6)
#   Training XGBoost model for fold 7, iteration 6
#   Making predictions for fold 7, iteration 6
# Processing fold 8 of 10 (Iteration 6)
#   Training XGBoost model for fold 8, iteration 6
#   Making predictions for fold 8, iteration 6
# Processing fold 9 of 10 (Iteration 6)
#   Training XGBoost model for fold 9, iteration 6
#   Making predictions for fold 9, iteration 6
# Processing fold 10 of 10 (Iteration 6)
#   Training XGBoost model for fold 10, iteration 6
#   Making predictions for fold 10, iteration 6
# Saved intermediate predictions to Intermediate/AM_iter_6.csv
# Processing fold 1 of 10 (Iteration 7)
#   Training XGBoost model for fold 1, iteration 7
#   Making predictions for fold 1, iteration 7
# Processing fold 2 of 10 (Iteration 7)
#   Training XGBoost model for fold 2, iteration 7
#   Making predictions for fold 2, iteration 7
# Processing fold 3 of 10 (Iteration 7)
#   Training XGBoost model for fold 3, iteration 7
#   Making predictions for fold 3, iteration 7
# Processing fold 4 of 10 (Iteration 7)
#   Training XGBoost model for fold 4, iteration 7
#   Making predictions for fold 4, iteration 7
# Processing fold 5 of 10 (Iteration 7)
#   Training XGBoost model for fold 5, iteration 7
#   Making predictions for fold 5, iteration 7
# Processing fold 6 of 10 (Iteration 7)
#   Training XGBoost model for fold 6, iteration 7
#   Making predictions for fold 6, iteration 7
# Processing fold 7 of 10 (Iteration 7)
#   Training XGBoost model for fold 7, iteration 7
#   Making predictions for fold 7, iteration 7
# Processing fold 8 of 10 (Iteration 7)
#   Training XGBoost model for fold 8, iteration 7
#   Making predictions for fold 8, iteration 7
# Processing fold 9 of 10 (Iteration 7)
#   Training XGBoost model for fold 9, iteration 7
#   Making predictions for fold 9, iteration 7
# Processing fold 10 of 10 (Iteration 7)
#   Training XGBoost model for fold 10, iteration 7
#   Making predictions for fold 10, iteration 7
# Saved intermediate predictions to Intermediate/AM_iter_7.csv
# Processing fold 1 of 10 (Iteration 8)
#   Training XGBoost model for fold 1, iteration 8
#   Making predictions for fold 1, iteration 8
# Processing fold 2 of 10 (Iteration 8)
#   Training XGBoost model for fold 2, iteration 8
#   Making predictions for fold 2, iteration 8
# Processing fold 3 of 10 (Iteration 8)
#   Training XGBoost model for fold 3, iteration 8
#   Making predictions for fold 3, iteration 8
# Processing fold 4 of 10 (Iteration 8)
#   Training XGBoost model for fold 4, iteration 8
#   Making predictions for fold 4, iteration 8
# Processing fold 5 of 10 (Iteration 8)
#   Training XGBoost model for fold 5, iteration 8
#   Making predictions for fold 5, iteration 8
# Processing fold 6 of 10 (Iteration 8)
#   Training XGBoost model for fold 6, iteration 8
#   Making predictions for fold 6, iteration 8
# Processing fold 7 of 10 (Iteration 8)
#   Training XGBoost model for fold 7, iteration 8
#   Making predictions for fold 7, iteration 8
# Processing fold 8 of 10 (Iteration 8)
#   Training XGBoost model for fold 8, iteration 8
#   Making predictions for fold 8, iteration 8
# Processing fold 9 of 10 (Iteration 8)
#   Training XGBoost model for fold 9, iteration 8
#   Making predictions for fold 9, iteration 8
# Processing fold 10 of 10 (Iteration 8)
#   Training XGBoost model for fold 10, iteration 8
#   Making predictions for fold 10, iteration 8
# Saved intermediate predictions to Intermediate/AM_iter_8.csv
# Processing fold 1 of 10 (Iteration 9)
#   Training XGBoost model for fold 1, iteration 9
#   Making predictions for fold 1, iteration 9
# Processing fold 2 of 10 (Iteration 9)
#   Training XGBoost model for fold 2, iteration 9
#   Making predictions for fold 2, iteration 9
# Processing fold 3 of 10 (Iteration 9)
#   Training XGBoost model for fold 3, iteration 9
#   Making predictions for fold 3, iteration 9
# Processing fold 4 of 10 (Iteration 9)
#   Training XGBoost model for fold 4, iteration 9
#   Making predictions for fold 4, iteration 9
# Processing fold 5 of 10 (Iteration 9)
#   Training XGBoost model for fold 5, iteration 9
#   Making predictions for fold 5, iteration 9
# Processing fold 6 of 10 (Iteration 9)
#   Training XGBoost model for fold 6, iteration 9
#   Making predictions for fold 6, iteration 9
# Processing fold 7 of 10 (Iteration 9)
#   Training XGBoost model for fold 7, iteration 9
#   Making predictions for fold 7, iteration 9
# Processing fold 8 of 10 (Iteration 9)
#   Training XGBoost model for fold 8, iteration 9
#   Making predictions for fold 8, iteration 9
# Processing fold 9 of 10 (Iteration 9)
#   Training XGBoost model for fold 9, iteration 9
#   Making predictions for fold 9, iteration 9
# Processing fold 10 of 10 (Iteration 9)
#   Training XGBoost model for fold 10, iteration 9
#   Making predictions for fold 10, iteration 9
# Saved intermediate predictions to Intermediate/AM_iter_9.csv
# Processing fold 1 of 10 (Iteration 10)
#   Training XGBoost model for fold 1, iteration 10
#   Making predictions for fold 1, iteration 10
# Processing fold 2 of 10 (Iteration 10)
#   Training XGBoost model for fold 2, iteration 10
#   Making predictions for fold 2, iteration 10
# Processing fold 3 of 10 (Iteration 10)
#   Training XGBoost model for fold 3, iteration 10
#   Making predictions for fold 3, iteration 10
# Processing fold 4 of 10 (Iteration 10)
#   Training XGBoost model for fold 4, iteration 10
#   Making predictions for fold 4, iteration 10
# Processing fold 5 of 10 (Iteration 10)
#   Training XGBoost model for fold 5, iteration 10
#   Making predictions for fold 5, iteration 10
# Processing fold 6 of 10 (Iteration 10)
#   Training XGBoost model for fold 6, iteration 10
#   Making predictions for fold 6, iteration 10
# Processing fold 7 of 10 (Iteration 10)
#   Training XGBoost model for fold 7, iteration 10
#   Making predictions for fold 7, iteration 10
# Processing fold 8 of 10 (Iteration 10)
#   Training XGBoost model for fold 8, iteration 10
#   Making predictions for fold 8, iteration 10
# Processing fold 9 of 10 (Iteration 10)
#   Training XGBoost model for fold 9, iteration 10
#   Making predictions for fold 9, iteration 10
# Processing fold 10 of 10 (Iteration 10)
#   Training XGBoost model for fold 10, iteration 10
#   Making predictions for fold 10, iteration 10
# Saved intermediate predictions to Intermediate/AM_iter_10.csv
# Processing fold 1 of 10 (Iteration 11)
#   Training XGBoost model for fold 1, iteration 11
#   Making predictions for fold 1, iteration 11
# Processing fold 2 of 10 (Iteration 11)
#   Training XGBoost model for fold 2, iteration 11
#   Making predictions for fold 2, iteration 11
# Processing fold 3 of 10 (Iteration 11)
#   Training XGBoost model for fold 3, iteration 11
#   Making predictions for fold 3, iteration 11
# Processing fold 4 of 10 (Iteration 11)
#   Training XGBoost model for fold 4, iteration 11
#   Making predictions for fold 4, iteration 11
# Processing fold 5 of 10 (Iteration 11)
#   Training XGBoost model for fold 5, iteration 11
#   Making predictions for fold 5, iteration 11
# Processing fold 6 of 10 (Iteration 11)
#   Training XGBoost model for fold 6, iteration 11
#   Making predictions for fold 6, iteration 11
# Processing fold 7 of 10 (Iteration 11)
#   Training XGBoost model for fold 7, iteration 11
#   Making predictions for fold 7, iteration 11
# Processing fold 8 of 10 (Iteration 11)
#   Training XGBoost model for fold 8, iteration 11
#   Making predictions for fold 8, iteration 11
# Processing fold 9 of 10 (Iteration 11)
#   Training XGBoost model for fold 9, iteration 11
#   Making predictions for fold 9, iteration 11
# Processing fold 10 of 10 (Iteration 11)
#   Training XGBoost model for fold 10, iteration 11
#   Making predictions for fold 10, iteration 11
# Saved intermediate predictions to Intermediate/AM_iter_11.csv
# Processing fold 1 of 10 (Iteration 12)
#   Training XGBoost model for fold 1, iteration 12
#   Making predictions for fold 1, iteration 12
# Processing fold 2 of 10 (Iteration 12)
#   Training XGBoost model for fold 2, iteration 12
#   Making predictions for fold 2, iteration 12
# Processing fold 3 of 10 (Iteration 12)
#   Training XGBoost model for fold 3, iteration 12
#   Making predictions for fold 3, iteration 12
# Processing fold 4 of 10 (Iteration 12)
#   Training XGBoost model for fold 4, iteration 12
#   Making predictions for fold 4, iteration 12
# Processing fold 5 of 10 (Iteration 12)
#   Training XGBoost model for fold 5, iteration 12
#   Making predictions for fold 5, iteration 12
# Processing fold 6 of 10 (Iteration 12)
#   Training XGBoost model for fold 6, iteration 12
#   Making predictions for fold 6, iteration 12
# Processing fold 7 of 10 (Iteration 12)
#   Training XGBoost model for fold 7, iteration 12
#   Making predictions for fold 7, iteration 12
# Processing fold 8 of 10 (Iteration 12)
#   Training XGBoost model for fold 8, iteration 12
#   Making predictions for fold 8, iteration 12
# Processing fold 9 of 10 (Iteration 12)
#   Training XGBoost model for fold 9, iteration 12
#   Making predictions for fold 9, iteration 12
# Processing fold 10 of 10 (Iteration 12)
#   Training XGBoost model for fold 10, iteration 12
#   Making predictions for fold 10, iteration 12
# Saved intermediate predictions to Intermediate/AM_iter_12.csv
# Processing fold 1 of 10 (Iteration 13)
#   Training XGBoost model for fold 1, iteration 13
#   Making predictions for fold 1, iteration 13
# Processing fold 2 of 10 (Iteration 13)
#   Training XGBoost model for fold 2, iteration 13
#   Making predictions for fold 2, iteration 13
# Processing fold 3 of 10 (Iteration 13)
#   Training XGBoost model for fold 3, iteration 13
#   Making predictions for fold 3, iteration 13
# Processing fold 4 of 10 (Iteration 13)
#   Training XGBoost model for fold 4, iteration 13
#   Making predictions for fold 4, iteration 13
# Processing fold 5 of 10 (Iteration 13)
#   Training XGBoost model for fold 5, iteration 13
#   Making predictions for fold 5, iteration 13
# Processing fold 6 of 10 (Iteration 13)
#   Training XGBoost model for fold 6, iteration 13
#   Making predictions for fold 6, iteration 13
# Processing fold 7 of 10 (Iteration 13)
# ...
#   Training XGBoost model for fold 5, iteration 11
#   Making predictions for fold 5, iteration 11
# Processing fold 6 of 10 (Iteration 11)
#   Training XGBoost model for fold 6, iteration 11
#   Making predictions for fold 6, iteration 11
# Processing fold 7 of 10 (Iteration 11)
#   Training XGBoost model for fold 7, iteration 11
#   Making predictions for fold 7, iteration 11
# Processing fold 8 of 10 (Iteration 11)
#   Training XGBoost model for fold 8, iteration 11
#   Making predictions for fold 8, iteration 11
# Processing fold 9 of 10 (Iteration 11)
#   Training XGBoost model for fold 9, iteration 11
#   Making predictions for fold 9, iteration 11
# Processing fold 10 of 10 (Iteration 11)
#   Training XGBoost model for fold 10, iteration 11
#   Making predictions for fold 10, iteration 11
# Saved intermediate predictions to Intermediate/AMP_iter_11.csv
# Processing fold 1 of 10 (Iteration 12)
#   Training XGBoost model for fold 1, iteration 12
#   Making predictions for fold 1, iteration 12
# Processing fold 2 of 10 (Iteration 12)
#   Training XGBoost model for fold 2, iteration 12
#   Making predictions for fold 2, iteration 12
# Processing fold 3 of 10 (Iteration 12)
#   Training XGBoost model for fold 3, iteration 12
#   Making predictions for fold 3, iteration 12
# Processing fold 4 of 10 (Iteration 12)
#   Training XGBoost model for fold 4, iteration 12
#   Making predictions for fold 4, iteration 12
# Processing fold 5 of 10 (Iteration 12)
#   Training XGBoost model for fold 5, iteration 12
#   Making predictions for fold 5, iteration 12
# Processing fold 6 of 10 (Iteration 12)
#   Training XGBoost model for fold 6, iteration 12
#   Making predictions for fold 6, iteration 12
# Processing fold 7 of 10 (Iteration 12)
#   Training XGBoost model for fold 7, iteration 12
#   Making predictions for fold 7, iteration 12
# Processing fold 8 of 10 (Iteration 12)
#   Training XGBoost model for fold 8, iteration 12
#   Making predictions for fold 8, iteration 12
# Processing fold 9 of 10 (Iteration 12)
#   Training XGBoost model for fold 9, iteration 12
#   Making predictions for fold 9, iteration 12
# Processing fold 10 of 10 (Iteration 12)
#   Training XGBoost model for fold 10, iteration 12
#   Making predictions for fold 10, iteration 12
# Saved intermediate predictions to Intermediate/AMP_iter_12.csv
# Processing fold 1 of 10 (Iteration 13)
#   Training XGBoost model for fold 1, iteration 13
#   Making predictions for fold 1, iteration 13
# Processing fold 2 of 10 (Iteration 13)
#   Training XGBoost model for fold 2, iteration 13
#   Making predictions for fold 2, iteration 13
# Processing fold 3 of 10 (Iteration 13)
#   Training XGBoost model for fold 3, iteration 13
#   Making predictions for fold 3, iteration 13
# Processing fold 4 of 10 (Iteration 13)
#   Training XGBoost model for fold 4, iteration 13
#   Making predictions for fold 4, iteration 13
# Processing fold 5 of 10 (Iteration 13)
#   Training XGBoost model for fold 5, iteration 13
#   Making predictions for fold 5, iteration 13
# Processing fold 6 of 10 (Iteration 13)
#   Training XGBoost model for fold 6, iteration 13
#   Making predictions for fold 6, iteration 13
# Processing fold 7 of 10 (Iteration 13)
#   Training XGBoost model for fold 7, iteration 13
#   Making predictions for fold 7, iteration 13
# Processing fold 8 of 10 (Iteration 13)
#   Training XGBoost model for fold 8, iteration 13
#   Making predictions for fold 8, iteration 13
# Processing fold 9 of 10 (Iteration 13)
#   Training XGBoost model for fold 9, iteration 13
#   Making predictions for fold 9, iteration 13
# Processing fold 10 of 10 (Iteration 13)
#   Training XGBoost model for fold 10, iteration 13
#   Making predictions for fold 10, iteration 13
# Saved intermediate predictions to Intermediate/AMP_iter_13.csv
# Processing fold 1 of 10 (Iteration 14)
#   Training XGBoost model for fold 1, iteration 14
#   Making predictions for fold 1, iteration 14
# Processing fold 2 of 10 (Iteration 14)
#   Training XGBoost model for fold 2, iteration 14
#   Making predictions for fold 2, iteration 14
# Processing fold 3 of 10 (Iteration 14)
#   Training XGBoost model for fold 3, iteration 14
#   Making predictions for fold 3, iteration 14
# Processing fold 4 of 10 (Iteration 14)
#   Training XGBoost model for fold 4, iteration 14
#   Making predictions for fold 4, iteration 14
# Processing fold 5 of 10 (Iteration 14)
#   Training XGBoost model for fold 5, iteration 14
#   Making predictions for fold 5, iteration 14
# Processing fold 6 of 10 (Iteration 14)
#   Training XGBoost model for fold 6, iteration 14
#   Making predictions for fold 6, iteration 14
# Processing fold 7 of 10 (Iteration 14)
#   Training XGBoost model for fold 7, iteration 14
#   Making predictions for fold 7, iteration 14
# Processing fold 8 of 10 (Iteration 14)
#   Training XGBoost model for fold 8, iteration 14
#   Making predictions for fold 8, iteration 14
# Processing fold 9 of 10 (Iteration 14)
#   Training XGBoost model for fold 9, iteration 14
#   Making predictions for fold 9, iteration 14
# Processing fold 10 of 10 (Iteration 14)
#   Training XGBoost model for fold 10, iteration 14
#   Making predictions for fold 10, iteration 14
# Saved intermediate predictions to Intermediate/AMP_iter_14.csv
# Processing fold 1 of 10 (Iteration 15)
#   Training XGBoost model for fold 1, iteration 15
#   Making predictions for fold 1, iteration 15
# Processing fold 2 of 10 (Iteration 15)
#   Training XGBoost model for fold 2, iteration 15
#   Making predictions for fold 2, iteration 15
# Processing fold 3 of 10 (Iteration 15)
#   Training XGBoost model for fold 3, iteration 15
#   Making predictions for fold 3, iteration 15
# Processing fold 4 of 10 (Iteration 15)
#   Training XGBoost model for fold 4, iteration 15
#   Making predictions for fold 4, iteration 15
# Processing fold 5 of 10 (Iteration 15)
#   Training XGBoost model for fold 5, iteration 15
#   Making predictions for fold 5, iteration 15
# Processing fold 6 of 10 (Iteration 15)
#   Training XGBoost model for fold 6, iteration 15
#   Making predictions for fold 6, iteration 15
# Processing fold 7 of 10 (Iteration 15)
#   Training XGBoost model for fold 7, iteration 15
#   Making predictions for fold 7, iteration 15
# Processing fold 8 of 10 (Iteration 15)
#   Training XGBoost model for fold 8, iteration 15
#   Making predictions for fold 8, iteration 15
# Processing fold 9 of 10 (Iteration 15)
#   Training XGBoost model for fold 9, iteration 15
#   Making predictions for fold 9, iteration 15
# Processing fold 10 of 10 (Iteration 15)
#   Training XGBoost model for fold 10, iteration 15
#   Making predictions for fold 10, iteration 15
# Saved intermediate predictions to Intermediate/AMP_iter_15.csv
# Processing fold 1 of 10 (Iteration 16)
#   Training XGBoost model for fold 1, iteration 16
#   Making predictions for fold 1, iteration 16
# Processing fold 2 of 10 (Iteration 16)
#   Training XGBoost model for fold 2, iteration 16
#   Making predictions for fold 2, iteration 16
# Processing fold 3 of 10 (Iteration 16)
#   Training XGBoost model for fold 3, iteration 16
#   Making predictions for fold 3, iteration 16
# Processing fold 4 of 10 (Iteration 16)
#   Training XGBoost model for fold 4, iteration 16
#   Making predictions for fold 4, iteration 16
# Processing fold 5 of 10 (Iteration 16)
#   Training XGBoost model for fold 5, iteration 16
#   Making predictions for fold 5, iteration 16
# Processing fold 6 of 10 (Iteration 16)
#   Training XGBoost model for fold 6, iteration 16
#   Making predictions for fold 6, iteration 16
# Processing fold 7 of 10 (Iteration 16)
#   Training XGBoost model for fold 7, iteration 16
#   Making predictions for fold 7, iteration 16
# Processing fold 8 of 10 (Iteration 16)
#   Training XGBoost model for fold 8, iteration 16
#   Making predictions for fold 8, iteration 16
# Processing fold 9 of 10 (Iteration 16)
#   Training XGBoost model for fold 9, iteration 16
#   Making predictions for fold 9, iteration 16
# Processing fold 10 of 10 (Iteration 16)
#   Training XGBoost model for fold 10, iteration 16
#   Making predictions for fold 10, iteration 16
# Saved intermediate predictions to Intermediate/AMP_iter_16.csv
# Processing fold 1 of 10 (Iteration 17)
#   Training XGBoost model for fold 1, iteration 17
#   Making predictions for fold 1, iteration 17
# Processing fold 2 of 10 (Iteration 17)
#   Training XGBoost model for fold 2, iteration 17
#   Making predictions for fold 2, iteration 17
# Processing fold 3 of 10 (Iteration 17)
#   Training XGBoost model for fold 3, iteration 17
#   Making predictions for fold 3, iteration 17
# Processing fold 4 of 10 (Iteration 17)
#   Training XGBoost model for fold 4, iteration 17
#   Making predictions for fold 4, iteration 17
# Processing fold 5 of 10 (Iteration 17)
#   Training XGBoost model for fold 5, iteration 17
#   Making predictions for fold 5, iteration 17
# Processing fold 6 of 10 (Iteration 17)
#   Training XGBoost model for fold 6, iteration 17
#   Making predictions for fold 6, iteration 17
# Processing fold 7 of 10 (Iteration 17)
#   Training XGBoost model for fold 7, iteration 17
#   Making predictions for fold 7, iteration 17
# Processing fold 8 of 10 (Iteration 17)
#   Training XGBoost model for fold 8, iteration 17
#   Making predictions for fold 8, iteration 17
# Processing fold 9 of 10 (Iteration 17)
#   Training XGBoost model for fold 9, iteration 17
#   Making predictions for fold 9, iteration 17
# Processing fold 10 of 10 (Iteration 17)
#   Training XGBoost model for fold 10, iteration 17
#   Making predictions for fold 10, iteration 17
# Saved intermediate predictions to Intermediate/AMP_iter_17.csv
# Processing fold 1 of 10 (Iteration 18)
#   Training XGBoost model for fold 1, iteration 18
#   Making predictions for fold 1, iteration 18
# Processing fold 2 of 10 (Iteration 18)
#   Training XGBoost model for fold 2, iteration 18
#   Making predictions for fold 2, iteration 18
# Processing fold 3 of 10 (Iteration 18)
#   Training XGBoost model for fold 3, iteration 18
#   Making predictions for fold 3, iteration 18
# Processing fold 4 of 10 (Iteration 18)
#   Training XGBoost model for fold 4, iteration 18
#   Making predictions for fold 4, iteration 18
# Processing fold 5 of 10 (Iteration 18)
#   Training XGBoost model for fold 5, iteration 18
#   Making predictions for fold 5, iteration 18
# Processing fold 6 of 10 (Iteration 18)
#   Training XGBoost model for fold 6, iteration 18
#   Making predictions for fold 6, iteration 18
# Processing fold 7 of 10 (Iteration 18)
#   Training XGBoost model for fold 7, iteration 18
#   Making predictions for fold 7, iteration 18
# Processing fold 8 of 10 (Iteration 18)
#   Training XGBoost model for fold 8, iteration 18
#   Making predictions for fold 8, iteration 18
# Processing fold 9 of 10 (Iteration 18)
#   Training XGBoost model for fold 9, iteration 18
#   Making predictions for fold 9, iteration 18
# Processing fold 10 of 10 (Iteration 18)
#   Training XGBoost model for fold 10, iteration 18
#   Making predictions for fold 10, iteration 18
# Saved intermediate predictions to Intermediate/AMP_iter_18.csv
# Processing fold 1 of 10 (Iteration 19)
#   Training XGBoost model for fold 1, iteration 19
#   Making predictions for fold 1, iteration 19
# Processing fold 2 of 10 (Iteration 19)
#   Training XGBoost model for fold 2, iteration 19
#   Making predictions for fold 2, iteration 19
# Processing fold 3 of 10 (Iteration 19)
#   Training XGBoost model for fold 3, iteration 19
#   Making predictions for fold 3, iteration 19
# Processing fold 4 of 10 (Iteration 19)
#   Training XGBoost model for fold 4, iteration 19
#   Making predictions for fold 4, iteration 19
# Processing fold 5 of 10 (Iteration 19)
#   Training XGBoost model for fold 5, iteration 19
#   Making predictions for fold 5, iteration 19
# Processing fold 6 of 10 (Iteration 19)
#   Training XGBoost model for fold 6, iteration 19
#   Making predictions for fold 6, iteration 19
# Processing fold 7 of 10 (Iteration 19)
#   Training XGBoost model for fold 7, iteration 19
#   Making predictions for fold 7, iteration 19
# Processing fold 8 of 10 (Iteration 19)
#   Training XGBoost model for fold 8, iteration 19
#   Making predictions for fold 8, iteration 19
# Processing fold 9 of 10 (Iteration 19)
#   Training XGBoost model for fold 9, iteration 19
#   Making predictions for fold 9, iteration 19
# Processing fold 10 of 10 (Iteration 19)
#   Training XGBoost model for fold 10, iteration 19
#   Making predictions for fold 10, iteration 19
# Saved intermediate predictions to Intermediate/AMP_iter_19.csv
# Re-reading partial predictions from AMP to combine everything.
# Concatenating results from all folds/iterations for final stats.
# Analysis completed for dataset: AMP
# Results added for AMP
# Control results added for AMP
# All predictions added for AMP
# Group labels recorded for AMP
#
# Preparing final consolidated results
# All results saved to ..._All_Results.xlsx
# Control results saved to ..._Control_Results.xlsx
# All mouse predictions saved to ..._All_Predictions_All_Groups.xlsx
#
# Total execution time: 20778.36 seconds
#
# Summary of results:
# All results shape: (720, 6)
# Control results shape: (3000, 6)
#
# Group labels:
# FM: {'M_Cont_12': 25, 'F_Cont_12': 23, 'M_Cana': 15, 'M_Aca': 14, 'M_Young': 14, 'M_17aE2': 14, 'M_Rapa': 13, 'F_Aca': 13, 'M_CR': 13, 'F_Cana': 12, 'M_SnellWT': 12, 'F_Young': 12, 'F_17aE2': 12, 'F_CR': 11, 'F_Rapa': 11, 'M_DW': 10, 'M_GHWT': 10, 'F_GHWT': 10, 'F_SnellWT': 9, 'F_GHRKO': 9, 'M_GHRKO': 8, 'F_DW': 8}
# AM: {'M_Cont_12': 25, 'F_Cont_12': 23, 'M_Cana': 15, 'M_Aca': 14, 'M_Young': 14, 'M_17aE2': 14, 'M_Rapa': 13, 'F_Aca': 13, 'M_CR': 13, 'F_Cana': 12, 'M_SnellWT': 12, 'F_Young': 12, 'F_17aE2': 12, 'F_CR': 11, 'F_Rapa': 11, 'M_DW': 10, 'M_GHWT': 10, 'F_GHWT': 10, 'F_SnellWT': 9, 'F_GHRKO': 9, 'M_GHRKO': 8, 'F_DW': 8}
# AP: {'M_Cont_12': 26, 'F_Cont_12': 26, 'M_CR': 14, 'M_Aca': 14, 'M_17aE2': 14, 'M_Cana': 14, 'M_Young': 14, 'M_Rapa': 14, 'F_Rapa': 13, 'F_Aca': 13, 'F_Cana': 13, 'F_Young': 13, 'F_17aE2': 13, 'F_CR': 12, 'M_SnellWT': 12, 'M_DW': 10, 'M_GHWT': 10, 'F_GHWT': 10, 'F_GHRKO': 9, 'M_GHRKO': 9, 'F_DW': 9, 'F_SnellWT': 9}
# FP: {'M_Cont_12': 26, 'F_Cont_12': 26, 'M_CR': 14, 'M_Aca': 14, 'M_17aE2': 14, 'M_Cana': 14, 'M_Young': 14, 'M_Rapa': 14, 'F_Rapa': 13, 'F_Aca': 13, 'F_Cana': 13, 'F_Young': 13, 'F_17aE2': 13, 'F_CR': 12, 'M_SnellWT': 12, 'M_DW': 10, 'M_GHWT': 10, 'F_GHWT': 10, 'F_GHRKO': 9, 'M_GHRKO': 9, 'F_DW': 9, 'F_SnellWT': 9}
# FMP: {'M_Cont_12': 24, 'F_Cont_12': 23, 'M_Cana': 17, 'F_Aca': 15, 'M_Aca': 14, 'M_17aE2': 14, 'M_Rapa': 13, 'M_CR': 12, 'F_17aE2': 12, 'F_Cana': 12, 'M_SnellWT': 12, 'F_CR': 11, 'F_Rapa': 11, 'F_GHRKO': 11, 'M_GHWT': 10, 'F_GHWT': 10, 'M_DW': 10, 'F_SnellWT': 9, 'M_GHRKO': 8, 'F_DW': 8}
# AMP: {'M_Cont_12': 24, 'F_Cont_12': 23, 'M_Cana': 17, 'F_Aca': 15, 'M_Aca': 14, 'M_17aE2': 14, 'M_Rapa': 13, 'M_CR': 12, 'F_17aE2': 12, 'F_Cana': 12, 'M_SnellWT': 12, 'F_CR': 11, 'F_Rapa': 11, 'F_GHRKO': 11, 'M_GHWT': 10, 'F_GHWT': 10, 'M_DW': 10, 'F_SnellWT': 9, 'M_GHRKO': 8, 'F_DW': 8}
#
# Dataset: FM
#   M_17aE2: Mean = 14.36, Std = 1.04
#   M_Aca: Mean = 18.85, Std = 0.58
#   M_CR: Mean = 25.83, Std = 1.52
#   M_Cana: Mean = 16.16, Std = 0.96
#   M_Cont_12: Mean = 6.36, Std = 1.25
#   M_Rapa: Mean = 14.41, Std = 1.24
#
# Dataset: AM
#   M_17aE2: Mean = 14.60, Std = 1.18
#   M_Aca: Mean = 18.91, Std = 0.71
#   M_CR: Mean = 26.08, Std = 0.83
#   M_Cana: Mean = 16.63, Std = 0.97
#   M_Cont_12: Mean = 6.13, Std = 1.07
#   M_Rapa: Mean = 14.07, Std = 1.24
#
# Dataset: AP
#   M_17aE2: Mean = 13.04, Std = 0.75
#   M_Aca: Mean = 14.07, Std = 1.18
#   M_CR: Mean = 22.83, Std = 1.25
#   M_Cana: Mean = 15.13, Std = 0.86
#   M_Cont_12: Mean = 12.45, Std = 0.69
#   M_Rapa: Mean = 15.54, Std = 0.86
#
# Dataset: FP
#   M_17aE2: Mean = 13.62, Std = 0.51
#   M_Aca: Mean = 15.29, Std = 1.12
#   M_CR: Mean = 23.94, Std = 1.68
#   M_Cana: Mean = 15.77, Std = 1.24
#   M_Cont_12: Mean = 11.80, Std = 0.85
#   M_Rapa: Mean = 16.23, Std = 1.47
#
# Dataset: FMP
#   M_17aE2: Mean = 13.42, Std = 0.99
#   M_Aca: Mean = 17.40, Std = 1.02
#   M_CR: Mean = 24.80, Std = 1.30
#   M_Cana: Mean = 16.09, Std = 0.71
#   M_Cont_12: Mean = 7.19, Std = 0.84
#   M_Rapa: Mean = 16.19, Std = 1.17
#
# Dataset: AMP
#   M_17aE2: Mean = 14.70, Std = 0.69
#   M_Aca: Mean = 18.31, Std = 0.58
#   M_CR: Mean = 24.69, Std = 0.87
#   M_Cana: Mean = 16.12, Std = 0.81
#   M_Cont_12: Mean = 4.96, Std = 0.68
#   M_Rapa: Mean = 16.36, Std = 0.89

# %%
# in case you messed up where you saved the file, manually get concatinate it from Intermediate folder
import os
import glob
import pandas as pd
import numpy as np

# Set the intermediate folder where partial CSV files were saved
intermediate_dir = "Intermediate"

# Get all CSV files in the intermediate folder
csv_files = glob.glob(os.path.join(intermediate_dir, "*.csv"))
print(f"Found {len(csv_files)} intermediate CSV files.")

# Read each CSV file and store into a list of DataFrames
dfs = []
for file in csv_files:
    print(f"Reading file: {file}")
    df = pd.read_csv(file)
    dfs.append(df)

# Concatenate all the intermediate DataFrames into one final DataFrame
if dfs:
    all_predictions = pd.concat(dfs, ignore_index=True)
else:
    print("No intermediate CSV files found.")
    all_predictions = pd.DataFrame()

if not all_predictions.empty:
    # 1. All Results:
    # Group by Dataset, Grp_Sex, and Iteration and calculate the median and standard deviation of Prediction.
    all_results = (
        all_predictions
        .groupby(['Dataset', 'Grp_Sex', 'Iteration'])
        .agg({'Prediction': ['median', 'std']})
        .reset_index()
    )
    # Flatten the MultiIndex columns
    all_results.columns = ['Dataset', 'Grp_Sex', 'Iteration', 'Median_Prediction', 'Std_Dev_Prediction']

    # 2. Control Results:
    # For the control group (Grp_Sex == 'M_Cont_12'), group by Dataset, Grp_Sex, Mouse_ID, Actual, and Iteration,
    # then take the median of Prediction.
    control_results = (
        all_predictions[all_predictions['Grp_Sex'] == 'M_Cont_12']
        .groupby(['Dataset', 'Grp_Sex', 'Mouse_ID', 'Actual', 'Iteration'])['Prediction']
        .median()
        .reset_index()
    )

    # 3. All Predictions All Groups:
    # This is simply the concatenated DataFrame "all_predictions".

    # Define output prefix and file names
    output_prefix = "XGBoost_Analysis_10k_20i_details_fig1"
    all_results_file = f"{output_prefix}_All_Results.xlsx"
    control_results_file = f"{output_prefix}_Control_Results.xlsx"
    all_predictions_file = f"{output_prefix}_All_Predictions_All_Groups.xlsx"

    # Save final documents to Excel
    all_results.to_excel(all_results_file, index=False)
    control_results.to_excel(control_results_file, index=False)
    all_predictions.to_excel(all_predictions_file, index=False)

    print("Final documents saved:")
    print(f" - {all_results_file}")
    print(f" - {control_results_file}")
    print(f" - {all_predictions_file}")
else:
    print("No prediction data to process.")
# Out:
# Found 120 intermediate CSV files.
# Reading file: Intermediate/AM_iter_2.csv
# Reading file: Intermediate/FM_iter_17.csv
# Reading file: Intermediate/AP_iter_1.csv
# Reading file: Intermediate/AM_iter_0.csv
# Reading file: Intermediate/FM_iter_4.csv
# Reading file: Intermediate/AM_iter_9.csv
# Reading file: Intermediate/FMP_iter_2.csv
# Reading file: Intermediate/AM_iter_19.csv
# Reading file: Intermediate/FP_iter_14.csv
# Reading file: Intermediate/FMP_iter_18.csv
# Reading file: Intermediate/FMP_iter_11.csv
# Reading file: Intermediate/FP_iter_3.csv
# Reading file: Intermediate/FP_iter_11.csv
# Reading file: Intermediate/AM_iter_18.csv
# Reading file: Intermediate/AP_iter_5.csv
# Reading file: Intermediate/AMP_iter_13.csv
# Reading file: Intermediate/AP_iter_6.csv
# Reading file: Intermediate/AMP_iter_4.csv
# Reading file: Intermediate/FM_iter_1.csv
# Reading file: Intermediate/AMP_iter_11.csv
# Reading file: Intermediate/AP_iter_3.csv
# Reading file: Intermediate/AMP_iter_19.csv
# Reading file: Intermediate/AM_iter_4.csv
# Reading file: Intermediate/AM_iter_16.csv
# Reading file: Intermediate/AM_iter_14.csv
# Reading file: Intermediate/FP_iter_8.csv
# Reading file: Intermediate/AM_iter_1.csv
# Reading file: Intermediate/FMP_iter_13.csv
# Reading file: Intermediate/AM_iter_8.csv
# Reading file: Intermediate/FM_iter_14.csv
# Reading file: Intermediate/FP_iter_5.csv
# Reading file: Intermediate/FP_iter_7.csv
# Reading file: Intermediate/FP_iter_4.csv
# Reading file: Intermediate/AM_iter_10.csv
# Reading file: Intermediate/AMP_iter_8.csv
# Reading file: Intermediate/AM_iter_6.csv
# Reading file: Intermediate/AP_iter_8.csv
# Reading file: Intermediate/FM_iter_2.csv
# Reading file: Intermediate/FP_iter_1.csv
# Reading file: Intermediate/AP_iter_4.csv
# Reading file: Intermediate/FMP_iter_8.csv
# Reading file: Intermediate/FM_iter_11.csv
# Reading file: Intermediate/FM_iter_6.csv
# Reading file: Intermediate/AMP_iter_2.csv
# Reading file: Intermediate/AM_iter_15.csv
# Reading file: Intermediate/AMP_iter_18.csv
# Reading file: Intermediate/AMP_iter_17.csv
# Reading file: Intermediate/FM_iter_19.csv
# Reading file: Intermediate/AM_iter_17.csv
# Reading file: Intermediate/FM_iter_9.csv
# Reading file: Intermediate/FP_iter_2.csv
# Reading file: Intermediate/FMP_iter_5.csv
# Reading file: Intermediate/AMP_iter_1.csv
# Reading file: Intermediate/FM_iter_16.csv
# Reading file: Intermediate/AMP_iter_7.csv
# Reading file: Intermediate/AM_iter_5.csv
# Reading file: Intermediate/FMP_iter_17.csv
# Reading file: Intermediate/AP_iter_9.csv
# Reading file: Intermediate/AP_iter_12.csv
# Reading file: Intermediate/FP_iter_13.csv
# Reading file: Intermediate/FM_iter_5.csv
# Reading file: Intermediate/FP_iter_6.csv
# Reading file: Intermediate/FMP_iter_12.csv
# Reading file: Intermediate/AP_iter_17.csv
# Reading file: Intermediate/AP_iter_18.csv
# Reading file: Intermediate/FMP_iter_0.csv
# Reading file: Intermediate/AP_iter_14.csv
# Reading file: Intermediate/FMP_iter_4.csv
# Reading file: Intermediate/AP_iter_11.csv
# Reading file: Intermediate/FM_iter_13.csv
# Reading file: Intermediate/FMP_iter_7.csv
# Reading file: Intermediate/FMP_iter_19.csv
# Reading file: Intermediate/AMP_iter_10.csv
# Reading file: Intermediate/AMP_iter_9.csv
# Reading file: Intermediate/AP_iter_7.csv
# Reading file: Intermediate/FM_iter_0.csv
# Reading file: Intermediate/AP_iter_2.csv
# Reading file: Intermediate/FM_iter_8.csv
# Reading file: Intermediate/FP_iter_18.csv
# Reading file: Intermediate/AP_iter_13.csv
# Reading file: Intermediate/FP_iter_9.csv
# Reading file: Intermediate/AM_iter_7.csv
# Reading file: Intermediate/AMP_iter_6.csv
# Reading file: Intermediate/AP_iter_0.csv
# Reading file: Intermediate/FMP_iter_15.csv
# Reading file: Intermediate/FM_iter_18.csv
# Reading file: Intermediate/AM_iter_11.csv
# Reading file: Intermediate/FP_iter_10.csv
# Reading file: Intermediate/FP_iter_17.csv
# Reading file: Intermediate/FMP_iter_14.csv
# Reading file: Intermediate/AM_iter_13.csv
# Reading file: Intermediate/AMP_iter_12.csv
# Reading file: Intermediate/FM_iter_10.csv
# Reading file: Intermediate/FM_iter_12.csv
# Reading file: Intermediate/FP_iter_12.csv
# Reading file: Intermediate/FP_iter_15.csv
# Reading file: Intermediate/FMP_iter_9.csv
# Reading file: Intermediate/FMP_iter_1.csv
# Reading file: Intermediate/AP_iter_16.csv
# Reading file: Intermediate/FM_iter_7.csv
# Reading file: Intermediate/AMP_iter_15.csv
# Reading file: Intermediate/AMP_iter_16.csv
# Reading file: Intermediate/FMP_iter_6.csv
# Reading file: Intermediate/FP_iter_19.csv
# Reading file: Intermediate/AM_iter_12.csv
# Reading file: Intermediate/FMP_iter_3.csv
# Reading file: Intermediate/AMP_iter_14.csv
# Reading file: Intermediate/AMP_iter_0.csv
# Reading file: Intermediate/FP_iter_16.csv
# Reading file: Intermediate/AMP_iter_3.csv
# Reading file: Intermediate/FP_iter_0.csv
# Reading file: Intermediate/AP_iter_15.csv
# Reading file: Intermediate/AMP_iter_5.csv
# Reading file: Intermediate/AM_iter_3.csv
# Reading file: Intermediate/FM_iter_3.csv
# Reading file: Intermediate/AP_iter_10.csv
# Reading file: Intermediate/FMP_iter_10.csv
# Reading file: Intermediate/FM_iter_15.csv
# Reading file: Intermediate/AP_iter_19.csv
# Reading file: Intermediate/FMP_iter_16.csv
# Final documents saved:
#  - XGBoost_Analysis_10k_20i_details_fig1_All_Results.xlsx
#  - XGBoost_Analysis_10k_20i_details_fig1_Control_Results.xlsx
#  - XGBoost_Analysis_10k_20i_details_fig1_All_Predictions_All_Groups.xlsx

# %%
#write versions
import sys
import pkg_resources

# Get the Python version
python_version = sys.version

# Get the list of installed packages with versions
installed_packages = sorted(["{}=={}".format(d.project_name, d.version) for d in pkg_resources.working_set])

# Define output file
output_file = "../Paper_Figures/Package_Info/pythonStep2_environment.txt"

# Write to file
with open(output_file, "w") as f:
    f.write(f"Python Version:\n{python_version}\n\n")
    f.write("Installed Packages:\n")
    f.write("\n".join(installed_packages))

print(f"Python environment details saved to {output_file}")
# Out:
# Python environment details saved to ../Paper_Figures/Package_Info/pythonStep2_environment.txt
